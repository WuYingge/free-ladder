# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
sys.path.append("../libs")
import pandas as pd
from config import DataPath
from data_manager.etf_data_manager import batch_check_etf_data_updated, save_res_df_to_windows, sync_backup, update_etf_data
from data_manager.index_data_manager import batch_check_index_data_updated, update_index_data
from data_manager.providers.etf_list_provider import ETF_LIST
from data_manager.providers.index_list_provider import INDEX_LIST
from fetcher.etf import fund_etf_hist_em, get_all_ETF_fund, get_all_etf_code
from importlib import reload
import datetime
import numpy as np
from proxy.proxy import PROXY_POOL, get_proxy

# %%
sync_backup(src=DataPath.DEFAULT_PATH, dest=os.path.join(DataPath.BAK_PATH, "etf_data"))

# %%
from data_manager.etf_data_manager import batch_check_etf_data_updated
from data_manager.providers.etf_list_provider import ETF_LIST

symbols = ETF_LIST.get_all_symbol()
status_df = batch_check_etf_data_updated(symbols, target_date=None)  # or "2026-04-14"

# %%
failed_updated_list = status_df[~status_df["is_updated"]].symbol.tolist()

# %%
len(failed_updated_list)
# Out:
# 5

# %%
update_etf_data(failed_updated_list)
# Out:
# update 159100 in /home/gouzi/projects/invest/data/etf_data/159100.csv
# update 159101 in /home/gouzi/projects/invest/data/etf_data/159101.csv
# update 159152 in /home/gouzi/projects/invest/data/etf_data/159152.csv
# update 159153 in /home/gouzi/projects/invest/data/etf_data/159153.csv
# update 159383 in /home/gouzi/projects/invest/data/etf_data/159383.csv
# update 159385 in /home/gouzi/projects/invest/data/etf_data/159385.csv
# update 159537 in /home/gouzi/projects/invest/data/etf_data/159537.csv
# update 159576 in /home/gouzi/projects/invest/data/etf_data/159576.csv
# update 159652 in /home/gouzi/projects/invest/data/etf_data/159652.csv
# update 159650 in /home/gouzi/projects/invest/data/etf_data/159650.csv
# update 159660 in /home/gouzi/projects/invest/data/etf_data/159660.csv
# update 159672 in /home/gouzi/projects/invest/data/etf_data/159672.csv
# update 159673 in /home/gouzi/projects/invest/data/etf_data/159673.csv
# update 159723 in /home/gouzi/projects/invest/data/etf_data/159723.csv
# update 159691 in /home/gouzi/projects/invest/data/etf_data/159691.csv
# update 159725 in /home/gouzi/projects/invest/data/etf_data/159725.csv
# update 159852 in /home/gouzi/projects/invest/data/etf_data/159852.csv
# update 159969 in /home/gouzi/projects/invest/data/etf_data/159969.csv
# update 510510 in /home/gouzi/projects/invest/data/etf_data/510510.csv
# update 510500 in /home/gouzi/projects/invest/data/etf_data/510500.csv
# update 159886 in /home/gouzi/projects/invest/data/etf_data/159886.csv
# update 510530 in /home/gouzi/projects/invest/data/etf_data/510530.csv
# update 511130 in /home/gouzi/projects/invest/data/etf_data/511130.csv
# update 512030 in /home/gouzi/projects/invest/data/etf_data/512030.csv
# update 512390 in /home/gouzi/projects/invest/data/etf_data/512390.csv
# update 511150 in /home/gouzi/projects/invest/data/etf_data/511150.csv
# update 512900 in /home/gouzi/projects/invest/data/etf_data/512900.csv
# update 515130 in /home/gouzi/projects/invest/data/etf_data/515130.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 515730 in /home/gouzi/projects/invest/data/etf_data/515730.csv
# update 515150 in /home/gouzi/projects/invest/data/etf_data/515150.csv
# update 516360 in /home/gouzi/projects/invest/data/etf_data/516360.csv
# update 530580 in /home/gouzi/projects/invest/data/etf_data/530580.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 530680 in /home/gouzi/projects/invest/data/etf_data/530680.csv
# update 560360 in /home/gouzi/projects/invest/data/etf_data/560360.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 560890 in /home/gouzi/projects/invest/data/etf_data/560890.csv
# update 560000 in /home/gouzi/projects/invest/data/etf_data/560000.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 561570 in /home/gouzi/projects/invest/data/etf_data/561570.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 561960 in /home/gouzi/projects/invest/data/etf_data/561960.csv
# update 561580 in /home/gouzi/projects/invest/data/etf_data/561580.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 563620 in /home/gouzi/projects/invest/data/etf_data/563620.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 588030 in /home/gouzi/projects/invest/data/etf_data/588030.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 563630 in /home/gouzi/projects/invest/data/etf_data/563630.csv
# Failed to load listed ETF symbols due to Failed to fetch ETF spot data after retries, fallback to normal retry
# Acquiring data for 516163 for last 4000 days
# update 588420 in /home/gouzi/projects/invest/data/etf_data/588420.csv
# Retrying 516163 20150714-20150901 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 4 retries left
# Failed to load listed ETF symbols due to Failed to fetch ETF spot data after retries, fallback to normal retry
# Acquiring data for 515293 for last 4000 days
# update 589250 in /home/gouzi/projects/invest/data/etf_data/589250.csv
# Retrying 515293 20150714-20150901 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 4 retries left
# update 589260 in /home/gouzi/projects/invest/data/etf_data/589260.csv
# update 589270 in /home/gouzi/projects/invest/data/etf_data/589270.csv
# Traceback (most recent call last):
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 732, in _request_once
#     c.perform()
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/curl.py", line 505, in perform
#     self._check_error(ret, "perform")
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/curl.py", line 269, in _check_error
#     raise error
# curl_cffi.curl.CurlError: Failed to perform, curl: (28) Connection timed out after 3000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 183, in update
#     update_df = get_etf_certain_date_data(code, last_update, now)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 49, in get_etf_certain_date_data
#     return fund_etf_hist_em(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 95, in fund_etf_hist_em
#     r = request_get_via_proxy(url, timeout=15, params=params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 70, in request_get_via_proxy
#     raise last_err
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 54, in request_get_via_proxy
#     response = requests.get(
#                ^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/__init__.py", line 148, in get
#     return request(method="GET", url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/__init__.py", line 140, in request
#     return s.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 795, in request
#     return self._request_once(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 739, in _request_once
#     raise error(str(e), e.code, rsp) from e
# curl_cffi.requests.exceptions.Timeout: Failed to perform, curl: (28) Connection timed out after 3000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Can't update 561980 because: Failed to perform, curl: (28) Connection timed out after 3000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 589080 in /home/gouzi/projects/invest/data/etf_data/589080.csv
# Retrying 516163 20150714-20150901 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 3 retries left
# Retrying 516163 20150714-20150901 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 2 retries left
# Retrying 516163 20150714-20150901 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 1 retries left
# update 561980 in /home/gouzi/projects/invest/data/etf_data/561980.csv
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Retrying 515293 20230811-20230929 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 4 retries left
# Retrying 515293 20230811-20230929 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 3 retries left
# Retrying 515293 20230811-20230929 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 2 retries left
# Retrying 515293 20230811-20230929 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 1 retries left
# Retrying 515293 20230811-20230929 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 0 retries left
# Failed to get 515293 for slice 20230811-20230929, skip this symbol
# Failed update 515293: fetch failed, will retry
# Acquiring data for 515293 for last 4000 days
# Retrying 515293 20150714-20150901 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 4 retries left
# Retrying 515293 20150714-20150901 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 3 retries left
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Retrying 516163 20191011-20191129 due to Failed to perform, curl: (28) Connection timed out after 3031 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 4 retries left
# Retrying 516163 20191011-20191129 due to Failed to perform, curl: (28) Connection timed out after 3020 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 3 retries left
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Retrying 516163 20200617-20200805 due to Failed to perform, curl: (28) Connection timed out after 3001 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 4 retries left
# Retrying 516163 20200617-20200805 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 3 retries left
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Retrying 515293 20230811-20230929 due to Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details., 4 retries left
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# ProxyPool init failed for hailiang: Failed to acquire proxies after max retries
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Retrying 515293 20230811-20230929 due to Failed to acquire proxies after max retries, 3 retries left
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-30:
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 update_etf_data(failed_updated_list)
#
# File ~/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py:236, in update_etf_data(symbols)
#     234     return
#     235 with Pool(15, initializer=_initialize_etf_update_worker) as p:
# --> 236     res = p.map(update_single_etf_data, all_etf)
#     237 for code, result in res:
#     238     if result:
#
# File ~/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
os.makedirs(DataPath.INDEX_PATH, exist_ok=True)
sync_backup(src=DataPath.INDEX_PATH, dest=os.path.join(DataPath.BAK_PATH, "index"))

# %%
update_index_data()

# %%
index_symbols = INDEX_LIST.get_all_symbol()
index_status_df = batch_check_index_data_updated(index_symbols, target_date=None)
failed_index_update_list = index_status_df[~index_status_df["is_updated"]].symbol.tolist()
index_status_df

# %%
failed_index_update_list

# %%
update_index_data(failed_index_update_list)
