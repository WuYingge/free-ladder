# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
sys.path.append("../libs")
import pandas as pd
from config import DataPath
from data_manager.etf_data_manager import batch_check_etf_data_updated, save_res_df_to_windows, sync_backup, update_etf_data
from data_manager.index_data_manager import batch_check_index_data_updated, update_index_data
from data_manager.providers.etf_list_provider import ETF_LIST
from data_manager.providers.index_list_provider import INDEX_LIST
from fetcher.etf import fund_etf_hist_em, get_all_ETF_fund, get_all_etf_code
from importlib import reload
import datetime
import numpy as np
from proxy.proxy import PROXY_POOL, get_proxy

# %%
sync_backup(src=DataPath.DEFAULT_PATH, dest=os.path.join(DataPath.BAK_PATH, "etf_data"))

# %%
from data_manager.etf_data_manager import batch_check_etf_data_updated
from data_manager.providers.etf_list_provider import ETF_LIST

symbols = ETF_LIST.get_all_symbol()
status_df = batch_check_etf_data_updated(symbols, target_date=None)  # or "2026-04-14"

# %%
failed_updated_list = status_df[~status_df["is_updated"]].symbol.tolist()

# %%
len(failed_updated_list)
# Out:
# 13

# %%
update_etf_data(failed_updated_list)
# Out:
# update 159568 in /home/gouzi/projects/invest/data/etf_data/159568.csv
# update 159831 in /home/gouzi/projects/invest/data/etf_data/159831.csv
# update 159850 in /home/gouzi/projects/invest/data/etf_data/159850.csv
# update 159857 in /home/gouzi/projects/invest/data/etf_data/159857.csv
# update 159906 in /home/gouzi/projects/invest/data/etf_data/159906.csv
# Traceback (most recent call last):
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 732, in _request_once
#     c.perform()
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/curl.py", line 505, in perform
#     self._check_error(ret, "perform")
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/curl.py", line 269, in _check_error
#     raise error
# curl_cffi.curl.CurlError: Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 183, in update
#     update_df = get_etf_certain_date_data(code, last_update, now)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 49, in get_etf_certain_date_data
#     return fund_etf_hist_em(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 95, in fund_etf_hist_em
#     r = request_get_via_proxy(url, timeout=15, params=params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 70, in request_get_via_proxy
#     raise last_err
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 54, in request_get_via_proxy
#     response = requests.get(
#                ^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/__init__.py", line 148, in get
#     return request(method="GET", url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/__init__.py", line 140, in request
#     return s.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 795, in request
#     return self._request_once(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 739, in _request_once
#     raise error(str(e), e.code, rsp) from e
# curl_cffi.requests.exceptions.ConnectionError: Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Can't update 159969 because: Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 513520 in /home/gouzi/projects/invest/data/etf_data/513520.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# update 515980 in /home/gouzi/projects/invest/data/etf_data/515980.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Failed to load listed ETF symbols due to Failed to fetch ETF spot data after retries, fallback to normal retry
# Acquiring data for 515293 for last 4000 days
# update 560000 in /home/gouzi/projects/invest/data/etf_data/560000.csv
# Traceback (most recent call last):
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 732, in _request_once
#     c.perform()
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/curl.py", line 505, in perform
#     self._check_error(ret, "perform")
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/curl.py", line 269, in _check_error
#     raise error
# curl_cffi.curl.CurlError: Failed to perform, curl: (28) Connection timed out after 3000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 183, in update
#     update_df = get_etf_certain_date_data(code, last_update, now)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 49, in get_etf_certain_date_data
#     return fund_etf_hist_em(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 95, in fund_etf_hist_em
#     r = request_get_via_proxy(url, timeout=15, params=params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 70, in request_get_via_proxy
#     raise last_err
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 54, in request_get_via_proxy
#     response = requests.get(
#                ^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/__init__.py", line 148, in get
#     return request(method="GET", url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/__init__.py", line 140, in request
#     return s.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 795, in request
#     return self._request_once(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 739, in _request_once
#     raise error(str(e), e.code, rsp) from e
# curl_cffi.requests.exceptions.Timeout: Failed to perform, curl: (28) Connection timed out after 3000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Can't update 159969 because: Failed to perform, curl: (28) Connection timed out after 3000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Never do that again, can't execute update with args ('159969',)
# update 560650 in /home/gouzi/projects/invest/data/etf_data/560650.csv
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Traceback (most recent call last):
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 732, in _request_once
#     c.perform()
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/curl.py", line 505, in perform
#     self._check_error(ret, "perform")
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/curl.py", line 269, in _check_error
#     raise error
# curl_cffi.curl.CurlError: Failed to perform, curl: (28) Connection timed out after 3000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 183, in update
#     update_df = get_etf_certain_date_data(code, last_update, now)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 49, in get_etf_certain_date_data
#     return fund_etf_hist_em(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 95, in fund_etf_hist_em
#     r = request_get_via_proxy(url, timeout=15, params=params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 70, in request_get_via_proxy
#     raise last_err
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 54, in request_get_via_proxy
#     response = requests.get(
#                ^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/__init__.py", line 148, in get
#     return request(method="GET", url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/__init__.py", line 140, in request
#     return s.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 795, in request
#     return self._request_once(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/curl_cffi/requests/session.py", line 739, in _request_once
#     raise error(str(e), e.code, rsp) from e
# curl_cffi.requests.exceptions.Timeout: Failed to perform, curl: (28) Connection timed out after 3000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Failed to perform, curl: (56) Connection closed abruptly. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Can't update 560890 because: Failed to perform, curl: (28) Connection timed out after 3000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Can't get proxy due to Expecting value: line 1 column 1 (char 0), response is 您提取且未使用的IP太多，请优先使用已经提取的IP
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-21:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 374, in _fetch_proxies_from_api
#     js_res = self._decode_payload(response)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 374, in _fetch_proxies_from_api
#     js_res = self._decode_payload(response)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 374, in _fetch_proxies_from_api
#     js_res = self._decode_payload(response)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 374, in _fetch_proxies_from_api
#     js_res = self._decode_payload(response)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 374, in _fetch_proxies_from_api
#     js_res = self._decode_payload(response)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 291, in _decode_payload
#     return json.loads(response.content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 374, in _fetch_proxies_from_api
#     js_res = self._decode_payload(response)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 291, in _decode_payload
#     return json.loads(response.content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 374, in _fetch_proxies_from_api
#     js_res = self._decode_payload(response)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 291, in _decode_payload
#     return json.loads(response.content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 291, in _decode_payload
#     return json.loads(response.content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 291, in _decode_payload
#     return json.loads(response.content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 291, in _decode_payload
#     return json.loads(response.content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 338, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 291, in _decode_payload
#     return json.loads(response.content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/queues.py", line 387, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 338, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 338, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 338, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 338, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 356, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 356, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 356, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 356, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 338, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 356, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 338, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 356, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# KeyboardInterrupt
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# KeyboardInterrupt
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/json/decoder.py", line 356, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# During handling of the above exception, another exception occurred:
#
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 55, in _initialize_etf_update_worker
#     initialize_proxy_pool()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 55, in _initialize_etf_update_worker
#     initialize_proxy_pool()
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 55, in _initialize_etf_update_worker
#     initialize_proxy_pool()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 55, in _initialize_etf_update_worker
#     initialize_proxy_pool()
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 557, in initialize_proxy_pool
#     return PROXY_POOL.ensure_initialized()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 557, in initialize_proxy_pool
#     return PROXY_POOL.ensure_initialized()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 557, in initialize_proxy_pool
#     return PROXY_POOL.ensure_initialized()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 535, in ensure_initialized
#     return self._get_pool()
#            ^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 557, in initialize_proxy_pool
#     return PROXY_POOL.ensure_initialized()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 247, in update_single_etf_data
#     return code, update(code)
#                  ^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 535, in ensure_initialized
#     return self._get_pool()
#            ^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 535, in ensure_initialized
#     return self._get_pool()
#            ^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 535, in ensure_initialized
#     return self._get_pool()
#            ^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/utils/interval_utils.py", line 21, in wrapper
#     success = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 531, in _get_pool
#     self._pool = ProxyPool()
#                  ^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 55, in _initialize_etf_update_worker
#     initialize_proxy_pool()
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 531, in _get_pool
#     self._pool = ProxyPool()
#                  ^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 531, in _get_pool
#     self._pool = ProxyPool()
#                  ^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 183, in update
#     update_df = get_etf_certain_date_data(code, last_update, now)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 282, in __init__
#     self.pool = self._get_proxies()
#                 ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 531, in _get_pool
#     self._pool = ProxyPool()
#                  ^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 557, in initialize_proxy_pool
#     return PROXY_POOL.ensure_initialized()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 450, in _get_proxies
#     return self._fetch_proxies_from_api()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 282, in __init__
#     self.pool = self._get_proxies()
#                 ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 49, in get_etf_certain_date_data
#     return fund_etf_hist_em(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 282, in __init__
#     self.pool = self._get_proxies()
#                 ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 535, in ensure_initialized
#     return self._get_pool()
#            ^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 282, in __init__
#     self.pool = self._get_proxies()
#                 ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 383, in _fetch_proxies_from_api
#     time.sleep(retry_wait_sec)
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 450, in _get_proxies
#     return self._fetch_proxies_from_api()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 95, in fund_etf_hist_em
#     r = request_get_via_proxy(url, timeout=15, params=params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 247, in update_single_etf_data
#     return code, update(code)
#                  ^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 450, in _get_proxies
#     return self._fetch_proxies_from_api()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 450, in _get_proxies
#     return self._fetch_proxies_from_api()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 531, in _get_pool
#     self._pool = ProxyPool()
#                  ^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/utils/interval_utils.py", line 21, in wrapper
#     success = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 383, in _fetch_proxies_from_api
#     time.sleep(retry_wait_sec)
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 383, in _fetch_proxies_from_api
#     time.sleep(retry_wait_sec)
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 51, in request_get_via_proxy
#     proxy = get_proxy()
#             ^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 383, in _fetch_proxies_from_api
#     time.sleep(retry_wait_sec)
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 282, in __init__
#     self.pool = self._get_proxies()
#                 ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 190, in update
#     if _is_not_listed_yet(code):
#        ^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 569, in get_proxy
#     return PROXY_POOL.get_proxy()
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 450, in _get_proxies
#     return self._fetch_proxies_from_api()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 154, in _is_not_listed_yet
#     listed_symbols = _get_listed_etf_symbols()
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 538, in get_proxy
#     return self._get_pool().get_proxy()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 383, in _fetch_proxies_from_api
#     time.sleep(retry_wait_sec)
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 456, in get_proxy
#     self.refresh()
# KeyboardInterrupt
#   File "/home/gouzi/projects/invest/notebooks/../libs/data_manager/etf_data_manager.py", line 138, in _get_listed_etf_symbols
#     df = get_all_etf_code()
#          ^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 490, in refresh
#     self.pool = self._get_proxies()
#                 ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 26, in get_all_etf_code
#     all_etf = fund_etf_spot_em()
#               ^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 450, in _get_proxies
#     return self._fetch_proxies_from_api()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/etf.py", line 192, in fund_etf_spot_em
#     temp_df = fetch_paginated_data(url, params)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 383, in _fetch_proxies_from_api
#     time.sleep(retry_wait_sec)
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 89, in fetch_paginated_data
#     r = request_get_via_proxy(url, params=params, timeout=timeout)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/gouzi/projects/invest/notebooks/../libs/fetcher/utils.py", line 51, in request_get_via_proxy
#     proxy = get_proxy()
#             ^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 569, in get_proxy
#     return PROXY_POOL.get_proxy()
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 538, in get_proxy
#     return self._get_pool().get_proxy()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 456, in get_proxy
#     self.refresh()
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 490, in refresh
#     self.pool = self._get_proxies()
#                 ^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 450, in _get_proxies
#     return self._fetch_proxies_from_api()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gouzi/projects/invest/notebooks/../libs/proxy/proxy.py", line 383, in _fetch_proxies_from_api
#     time.sleep(retry_wait_sec)
# KeyboardInterrupt

# %%
os.makedirs(DataPath.INDEX_PATH, exist_ok=True)
sync_backup(src=DataPath.INDEX_PATH, dest=os.path.join(DataPath.BAK_PATH, "index"))

# %%
update_index_data()

# %%
index_symbols = INDEX_LIST.get_all_symbol()
index_status_df = batch_check_index_data_updated(index_symbols, target_date=None)
failed_index_update_list = index_status_df[~index_status_df["is_updated"]].symbol.tolist()
index_status_df

# %%
failed_index_update_list

# %%
update_index_data(failed_index_update_list)
