# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
from pathlib import Path

# Make local libs importable regardless of notebook working directory.
project_root = Path.cwd()
libs_path = (project_root / "libs") if (project_root / "libs").exists() else (project_root / ".." / "libs").resolve()
if str(libs_path) not in sys.path:
    sys.path.insert(0, str(libs_path))

import pandas as pd
from config import DataPath
from data_manager.etf_data_manager import etf_data_iter, save_res_df_to_windows, get_etf_data_by_symbols
from core.portfolios.portfolio import Portfolio, Position

from data_manager.providers.cluster_provider import ClusterInfo
from data_manager.providers.etf_list_provider import ETF_LIST
import datetime
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from factors.ma import SlopeRiskRatio
from factors.new_high import NewHigh
from factors.portfolio.correlation import CorrelationFactor
from factors.average_true_range import AverageTrueRange
from factors.change_since_new_high import ChangeSinceNewHigh

# %%
name_dict = ETF_LIST.name_dict()

# %%
my_portfolio = Portfolio(447000)

my_portfolio.add_position_with_symbol_quantities(
    ('159303', 13000),
    ('159326', 21500),
    ('159370', 11800),
    ('159502', 15900),
    ('159552', 9300),
    ('159603', 14100),
    ('159656', 18200),
    ('159755', 18800),
    ('159901', 5900),
    ('159967', 31700),
    ('159992', 25400),
    ('512800', 28000),
    ('515880', 21500),
    ('516720', 18800),
    ('520600', 16200),
    ('560710', 21000),
    ('561880', 16400),
    ('563030', 14300),
    ('588020', 9800)
)

# %%
baby_portfolio = Portfolio(41194.27)
baby_portfolio.add_position_with_symbol_quantities(
    ('588020', 9800)
)

# %%
mom_portfolio = Portfolio(133890)
mom_portfolio.add_position_with_symbol_quantities(
    ('159569', 8000),
    ('562550', 5600),
    ('563180', 10000)
)

# %%
today_dir = os.path.join(DataPath.DEFAULT_WINDOWS_PATH, "新高", (datetime.datetime.today()).strftime("%Y%m%d"))

# %%
def risk_concentration(corr_matrix):
    """风险集中度分析"""
    # 平均相关系数（衡量整体相关性）
    avg_corr = corr_matrix.values[np.triu_indices(len(corr_matrix), 1)].mean()
    
    # 相关性矩阵的特征值分析（衡量多元化程度）
    eigenvalues = np.linalg.eigvalsh(corr_matrix)
    eigenvalue_ratio = eigenvalues.max() / eigenvalues.sum()
    
    # 有效组合数（衡量真正独立的资产数量）
    if eigenvalues.sum() > 0:
        effective_n = (eigenvalues.sum()**2) / (eigenvalues**2).sum()
    else:
        effective_n = 0
    
    return {
        'average_correlation': avg_corr,
        'dominant_eigenvalue_ratio': eigenvalue_ratio,
        'effective_diversification_number': effective_n,
        'portfolio_concentration_score': eigenvalue_ratio * avg_corr
    }

# %%
def get_k_ratio_res(k):
    all_res = []
    for df in etf_data_iter():
        df.add_factors(SlopeRiskRatio())
        df.name = name_dict.get(df.symbol, "")
        res = df.calc_factors().tail(1)["SlopeRiskRatio"].values[0]
        all_res.append([df.symbol, df.name,res])
    save_res_df_to_windows(pd.DataFrame(all_res, columns=["code", "name", "ratio"]).sort_values(by="ratio", ascending=False), 
                           f"斜率风险比/{datetime.date.today().strftime('%Y%m%d')}-{k}倍.xlsx")

# %%
def generate_new_high_list(*portfolios):
    add_to_list = []
    sell_list = []
    if not os.path.exists(today_dir):
        os.mkdir(today_dir)
    new_high_factor = NewHigh(low_window=25, high_window=50, use_long_filter=False)
    change_since_new_high = ChangeSinceNewHigh(long_period=50, short_period=25, use_long_filter=False)
    for data in etf_data_iter():
        data.add_factors(new_high_factor)
        data.add_factors(change_since_new_high)
        data.calc_factors()
        data.name = name_dict.get(data.symbol, "")
        # print((data.factor_results[AverageTrueRange(window=50)].iloc[-1]  * 3 / data.data["close"].iloc[-1]) < data.factor_results[change_since_new_high].iloc[-1])
        # if (1 in data.factor_results[NewHigh()].iloc[-3:].values) and ((data.factor_results[AverageTrueRange(window=50)].iloc[-1]  * 3 / data.data["close"].iloc[-1]) < data.factor_results[change_since_new_high].iloc[-1]):
        if (1 in data.factor_results[new_high_factor].iloc[-5:].values):
            add_to_list.append(data.symbol)
            data.output_with_factors_to(today_dir)
        elif any([portfolio.has_symbol(data.symbol) for portfolio in portfolios]):
            data.output_with_factors_to(today_dir)
            if data.factor_results[new_high_factor].iloc[-1:].values == -1:
                sell_list.append(data.symbol)
    if sell_list:
        pd.DataFrame(sell_list, columns=["symbol"]).to_csv(os.path.join(today_dir, "sell.csv"), index=False, encoding="utf-8-sig")
    pd.DataFrame(add_to_list, columns=["symbol"]).to_csv(os.path.join(today_dir, "add.csv"), index=False, encoding="utf-8-sig")
    return add_to_list

# %%
def analysis_corr_between_add_and_hold(add_to, hold):
    hold_datas = get_etf_data_by_symbols(hold)
    add_datas = get_etf_data_by_symbols([i[0] for i in add_to])
    idx = []
    corr_analysis = []
    for num, add in enumerate(add_datas):
        idx.append(add.symbol)
        corr = CorrelationFactor()
        corrs_res = risk_concentration(corr(*([hold_data for hold_data in hold_datas] + [add])))
        corrs_res["name"] = add_to[num][1]
        corr_analysis.append(corrs_res)
    final_analysis_res = pd.DataFrame(corr_analysis, index=idx).sort_values(by="effective_diversification_number", ascending=False)
    
    final_analysis_res.to_excel(os.path.join(today_dir, "corr_analysis.xlsx"), index=True)
    return final_analysis_res

# %%
add_to_list = generate_new_high_list(my_portfolio, baby_portfolio, mom_portfolio)
# Out:
#   0%|          | 0/1484 [00:00<?, ?it/s]

# %%
today_dir
# Out:
# '/mnt/c/Users/wyg/Documents/invest/新高/20260423'

# %%
my_portfolio.analyze_with_add_to_list(
    add_to_list,
    name_dict,
    analysis_factors=[ChangeSinceNewHigh(long_period=50, short_period=25, use_long_filter=False)],
).to_excel(
    os.path.join(DataPath.DEFAULT_WINDOWS_PATH, "新高", today_dir, "add_with_corr.xlsx"), 
    index=True
)

# %%
my_portfolio.calc_clustering_distribution(name_dict=name_dict).to_excel(
    os.path.join(DataPath.DEFAULT_WINDOWS_PATH, "新高", today_dir, "my_portfolio.xlsx"),
    index=False
)

# %%
def get_sell_list():
    sell_path = os.path.join(DataPath.DEFAULT_WINDOWS_PATH, "新高", today_dir, "sell.csv")
    if not os.path.exists(sell_path):
        return
    sell_list = pd.read_csv(os.path.join(DataPath.DEFAULT_WINDOWS_PATH, "新高", today_dir, "sell.csv"),dtype="str").symbol.tolist()
    sell_map = {}
    sell_map["mom"] = []
    sell_map["baby"] = []
    sell_map["my"] = []
    for s in sell_list:
        if my_portfolio.has_symbol(s):
            sell_map["my"].append(s)
        if baby_portfolio.has_symbol(s):
            sell_map["baby"].append(s)
        if mom_portfolio.has_symbol(s):
            sell_map["mom"].append(s)
    for k, v in sell_map.items():
        print(f"{k} should sell {[s for s in v]}")
    return sell_map

# %%
get_sell_list()
