# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
sys.path.append("../libs")
import pandas as pd
from data_manager.etf_data_manager import etf_data_iter, save_res_df_to_windows, get_etf_data_by_symbols

from config import DataPath
import datetime
import numpy as np
# Out:
# /home/gouzi/projects/invest/.venv/lib/python3.12/site-packages/py_mini_racer/py_mini_racer.py:13: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
from factors.ma import SlopeRiskRatio
from factors.new_high import NewHigh
from factors.portfolio.correlation import CorrelationFactor
from factors.average_true_range import AverageTrueRange

# %%
from fetcher.etf import get_all_etf_code
all_codes = get_all_etf_code()
# Out:
# HTTPSConnectionPool(host='88.push2.eastmoney.com', port=443): Read timed out.

# %%
name_dict = all_codes[["代码", "名称"]].set_index("代码").to_dict().get("名称", {})

# %%
hold_list = [
    "159206",
    "560860",
    "159201",
    "516570",
    "159326",
    "513750",
    "159697",
    "560280",
    "513800",
    "159516"
]
all_money = 309104

# %%
def risk_concentration(corr_matrix):
    """风险集中度分析"""
    # 平均相关系数（衡量整体相关性）
    avg_corr = corr_matrix.values[np.triu_indices(len(corr_matrix), 1)].mean()
    
    # 相关性矩阵的特征值分析（衡量多元化程度）
    eigenvalues = np.linalg.eigvalsh(corr_matrix)
    eigenvalue_ratio = eigenvalues.max() / eigenvalues.sum()
    
    # 有效组合数（衡量真正独立的资产数量）
    if eigenvalues.sum() > 0:
        effective_n = (eigenvalues.sum()**2) / (eigenvalues**2).sum()
    else:
        effective_n = 0
    
    return {
        'average_correlation': avg_corr,
        'dominant_eigenvalue_ratio': eigenvalue_ratio,
        'effective_diversification_number': effective_n,
        'portfolio_concentration_score': eigenvalue_ratio * avg_corr
    }

# %%
def get_k_ratio_res(k):
    all_res = []
    for df in etf_data_iter():
        df.add_factors(SlopeRiskRatio())
        df.name = name_dict.get(df.symbol, "")
        res = df.calc_factors().tail(1)["SlopeRiskRatio"].values[0]
        all_res.append([df.symbol, df.name,res])
    save_res_df_to_windows(pd.DataFrame(all_res, columns=["code", "name", "ratio"]).sort_values(by="ratio", ascending=False), 
                           f"斜率风险比/{datetime.date.today().strftime('%Y%m%d')}-{k}倍.xlsx")

# %%
def generate_new_high_list(hold_list):
    add_to_list = []
    sell_list = []
    today_dir = os.path.join(DataPath.DEFAULT_WINDOWS_PATH, "新高", datetime.datetime.today().strftime("%Y%m%d"))
    if not os.path.exists(today_dir):
        os.mkdir(today_dir)
    for data in etf_data_iter():
        data.add_factors(NewHigh())
        data.calc_factors()
        data.name = name_dict[data.symbol]
        if 1 in data.factor_results["NewHigh"].iloc[-1:].values:
            add_to_list.append((data.symbol, data.name))
            data.output_with_factors_to(today_dir)
        elif data.symbol in hold_list:
            data.output_with_factors_to(today_dir)
            if data.factor_results["NewHigh"].iloc[-1] == -1:
                sell_list.append((data.symbol, data.name))
    if sell_list:
        pd.DataFrame(sell_list, columns=["symbol", "name"]).to_csv(os.path.join(today_dir, "sell.csv"), index=False, encoding="utf-8-sig")
    pd.DataFrame(add_to_list, columns=["symbol", "name"]).to_csv(os.path.join(today_dir, "add.csv"), index=False, encoding="utf-8-sig")
    return add_to_list

# %%
def analysis_corr_between_add_and_hold(add_to, hold):
    hold_datas = get_etf_data_by_symbols(hold)
    add_datas = get_etf_data_by_symbols([i[0] for i in add_to])
    idx = []
    corr_analysis = []
    for num, add in enumerate(add_datas):
        idx.append(add.symbol)
        corr = CorrelationFactor()
        corrs_res = risk_concentration(corr(*([hold_data for hold_data in hold_datas] + [add])))
        corrs_res["name"] = add_to[num][1]
        corr_analysis.append(corrs_res)
    final_analysis_res = pd.DataFrame(corr_analysis, index=idx).sort_values(by="effective_diversification_number", ascending=False)
    today_dir = os.path.join(DataPath.DEFAULT_WINDOWS_PATH, "新高", datetime.datetime.today().strftime("%Y%m%d"))
    final_analysis_res.to_excel(os.path.join(today_dir, "corr_analysis.xlsx"), index=True)
    return final_analysis_res

# %%
get_k_ratio_res(1)
# Out:
#   0%|          | 0/1326 [00:00<?, ?it/s]

# %%
add_to_list = generate_new_high_list(hold_list)
# Out:
#   0%|          | 0/1326 [00:00<?, ?it/s]

# %%
analysis_corr_between_add_and_hold(add_to_list, hold_list)
# Out:
#         average_correlation  dominant_eigenvalue_ratio  \
# 511820             0.439847                   0.546094
# 511160             0.432445                   0.546271
# 511970             0.429753                   0.546337
# 511880             0.420382                   0.547707
# 518600             0.461906                   0.549284
# ...                     ...                        ...
# 159677             0.560466                   0.620366
# 516120             0.559619                   0.620869
# 516020             0.559774                   0.620957
# 159944             0.560211                   0.621564
# 516570             0.559644                   0.621465
#
#         effective_diversification_number  portfolio_concentration_score  \
# 511820                          3.045271                       0.240198
# 511160                          3.042772                       0.236232
# 511970                          3.041939                       0.234790
# 511880                          3.028600                       0.230246
# 518600                          3.012562                       0.253717
# ...                                  ...                            ...
# 159677                          2.454776                       0.347694
# 516120                          2.451380                       0.347450
# 516020                          2.451161                       0.347596
# 159944                          2.444555                       0.348207
# 516570                          2.442559                       0.347799
#
#              name
# 511820    鹏华添利ETF
# 511160    国债ETF东财
# 511970    国寿货币ETF
# 511880    银华日利ETF
# 518600     上海金ETF
# ...           ...
# 159677  1000增强ETF
# 516120    化工50ETF
# 516020      化工ETF
# 159944      材料ETF
# 516570    化工行业ETF
#
# [94 rows x 5 columns]

# %%
for etf in get_etf_data_by_symbols(hold_list + [i[0] for i in add_to_list]):
    etf.add_factors(AverageTrueRange())
    res = etf.calc_factors()
    curr_atr = res.iloc[-1,-1]
    max_position = all_money * 0.003 / curr_atr
    print(f"Can buy etf {etf.symbol} {name_dict.get(etf.symbol)} no more than {max_position}")
# Out:
# Can buy etf 159206 卫星ETF no more than 19814.358974358965
# Can buy etf 560860 工业有色ETF no more than 22862.721893491107
# Can buy etf 159201 自由现金流ETF no more than 64040.88397790049
# Can buy etf 516570 化工行业ETF no more than 51289.38053097344
# Can buy etf 159326 电网设备ETF no more than 28834.328358208935
# Can buy etf 513750 港股通非银ETF no more than 27931.084337349403
# Can buy etf 159697 油气ETF no more than 44411.494252873694
# Can buy etf 560280 工程机械ETF no more than 35339.63414634144
# Can buy etf 513800 日本东证指数ETF no more than 49325.10638297868
# Can buy etf 159516 半导体设备ETF no more than 21932.63954588459
# Can buy etf 159870 化工ETF no more than 58839.593908629395
# Can buy etf 159516 半导体设备ETF no more than 21932.63954588459
# Can buy etf 516650 有色金属ETF基金 no more than 20264.685314685314
# Can buy etf 515880 通信ETF no more than 8241.308211873447
# Can buy etf 588240 科创200ETF指数 no more than 29382.50950570343
# Can buy etf 518680 金ETF no more than 9761.178947368435
# Can buy etf 159381 创业板人工智能ETF华夏 no more than 14663.377609108158
# Can buy etf 510560 国寿500ETF no more than 20680.46387154327
# Can buy etf 511820 鹏华添利ETF no more than 68996.42857142596
# Can buy etf 512680 军工ETF龙头 no more than 34756.821589205414
# Can buy etf 159249 A500增强ETF工银 no more than 59595.88688946005
# Can buy etf 159558 半导体设备ETF易方达 no more than 18832.493907392363
# Can buy etf 511880 银华日利ETF no more than 80495.83333334616
# Can buy etf 159511 通信ETF南方 no more than 17589.377845220042
# Can buy etf 518890 中银上海金ETF no more than 9627.408637873734
# Can buy etf 588270 科创200ETF易方达 no more than 29345.316455696215
# Can buy etf 512070 证券保险ETF no more than 19080.493827160502
# Can buy etf 159521 国证2000ETF指数基金 no more than 51289.38053097345
# Can buy etf 159628 国证2000ETF no more than 41471.91413237922
# Can buy etf 159830 上海金ETF no more than 9819.059720457417
# Can buy etf 159363 创业板人工智能ETF华宝 no more than 13462.717770034842
# Can buy etf 562660 中证2000ETF华夏 no more than 34092.35294117648
# Can buy etf 518850 黄金ETF华夏 no more than 9708.040201005033
# Can buy etf 159831 上海金ETF嘉实 no more than 38637.99999999996
# Can buy etf 511970 国寿货币ETF no more than 80217.3010380737
# Can buy etf 159638 高端装备ETF no more than 41695.683453237405
# Can buy etf 159652 有色50ETF no more than 21953.409090909092
# Can buy etf 512810 军工ETF华宝 no more than 31328.108108108107
# Can buy etf 159709 物联网ETF工银 no more than 27730.62200956938
# Can buy etf 159671 稀有金属ETF基金 no more than 26165.688487584663
# Can buy etf 511160 国债ETF东财 no more than 2575866.6666668234
# Can buy etf 560590 1000ETF增强 no more than 38066.99507389167
# Can buy etf 159994 5GETF no more than 14663.377609108158
# Can buy etf 159731 石化ETF no more than 54676.415094339645
# Can buy etf 560690 电信ETF基金 no more than 17576.042456406376
# Can buy etf 159906 深成长ETF大成 no more than 26224.88687782806
# Can buy etf 159241 航空航天ETF天弘 no more than 30423.622047244076
# Can buy etf 159690 矿业ETF no more than 18531.414868105505
# Can buy etf 516220 化工龙头ETF no more than 55461.24401913881
# Can buy etf 159876 有色ETF华宝 no more than 19064.802631578932
# Can buy etf 516570 化工行业ETF no more than 51289.38053097344
# Can buy etf 518660 黄金ETF基金 no more than 9769.405815423524
# Can buy etf 562800 稀有金属ETF no more than 36054.121306376335
# Can buy etf 588710 科创半导体设备ETF no more than 21249.12923923008
# Can buy etf 159934 黄金ETF no more than 9911.415134672907
# Can buy etf 159507 通信ETF广发 no more than 14663.377609108155
# Can buy etf 159804 创中盘88ETF no more than 31117.852348993292
# Can buy etf 159907 2000ETF no more than 28834.32835820895
# Can buy etf 159695 通信ETF no more than 13217.103762827832
# Can buy etf 588170 科创半导体ETF no more than 21788.345864661675
# Can buy etf 512660 军工ETF no more than 35942.32558139534
# Can buy etf 159834 金ETF no more than 38192.42174629323
# Can buy etf 159532 中证2000ETF易方达 no more than 34756.82158920543
# Can buy etf 159502 标普生物科技ETF no more than 28237.271619975632
# Can buy etf 159712 港股通50ETF no more than 45725.44378698219
# Can buy etf 159553 中证2000增强ETF海富通 no more than 25873.660714285696
# Can buy etf 159583 通信设备ETF no more than 10132.342657342664
# Can buy etf 159608 稀有金属ETF no more than 31455.630936227935
# Can buy etf 159980 有色ETF no more than 39094.097807757156
# Can buy etf 561280 中证1000ETF增强 no more than 40458.638743455485
# Can buy etf 159388 创业板人工智能ETF国泰 no more than 13478.37209302325
# Can buy etf 512400 有色金属ETF no more than 19159.33884297522
# Can buy etf 159918 中创400ETF no more than 21870.56603773584
# Can buy etf 159218 卫星产业ETF no more than 19985.172413793094
# Can buy etf 518880 黄金ETF no more than 9765.290648694185
# Can buy etf 510010 180治理ETF no more than 53171.559633027726
# Can buy etf 159880 有色ETF基金 no more than 19383.612040133787
# Can buy etf 512560 军工ETF易方达 no more than 29197.481108312313
# Can buy etf 562590 半导体材料ETF no more than 20960.94032549729
# Can buy etf 159677 1000增强ETF no more than 43658.75706214686
# Can buy etf 588820 科创200ETF基金 no more than 26894.19953596289
# Can buy etf 588230 科创200ETF no more than 27435.266272189314
# Can buy etf 518600 上海金ETF no more than 9992.586206896527
# Can buy etf 560780 芯片设备ETF no more than 20071.688311688293
# Can buy etf 159743 湖北ETF no more than 33794.16909620989
# Can buy etf 159937 黄金ETF基金 no more than 9839.898132427881
# Can buy etf 159881 有色60ETF no more than 19580.067567567563
# Can buy etf 516120 化工50ETF no more than 54805.67375886533
# Can buy etf 159812 黄金基金ETF no more than 8761.45124716552
# Can buy etf 516020 化工ETF no more than 54165.420560747654
# Can buy etf 159206 卫星ETF no more than 19814.358974358965
# Can buy etf 588070 科创板成长ETF no more than 20371.528998242527
# Can buy etf 159871 有色金属ETF no more than 19464.987405541557
# Can buy etf 518800 黄金基金ETF no more than 9949.699570815474
# Can buy etf 563300 中证2000ETF no more than 39226.39593908627
# Can buy etf 560860 工业有色ETF no more than 22862.721893491107
# Can buy etf 159944 材料ETF no more than 30383.74836173001
# Can buy etf 561330 矿业ETF no more than 19222.885572139316
# Can buy etf 561800 稀有金属ETF基金 no more than 34142.56259204712
# Can buy etf 510410 资源ETF no more than 27209.859154929567
# Can buy etf 515050 5G通信ETF no more than 11962.229102167174
# Can buy etf 159327 半导体设备ETF基金 no more than 18575.961538461554
# Can buy etf 159533 中证2000ETF基金 no more than 20371.528998242517
# Can buy etf 563200 中证2000ETF富国 no more than 35232.218844984774

# %%
all_money * 0.003
# Out:
# 918.0219900000001
